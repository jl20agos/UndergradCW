# %%
import numpy as np
import matplotlib.pyplot as plt
o = 1
b = 2
a 3
f 4
g 5
k 6
m 7

# %%
types = np.array([5, 6, 4, 3, 3, 2, 5, 3, 7, 7, 4, 6, 4, 5, 4, 4, 4, 4, 4, 2, 7, 3, 3, 7, 4, 2, 6, 4, 4, 3, 4, 6, 4, 2, 5, 3, 4, 4, 4, 5, 7, 3, 4, 3, 4, 4, 4, 4, 3, 4, 7, 5, 3, 3, 3, 3, 6, 3, 3, 3, 3, 3, 2, 6, 1, 2, 3, 2, 2, 3, 7, 3, 2, 4, 4, 6, 4, 4, 4, 4, 4, 4, 5, 4, 4, 4, 3, 3, 4, 6, 3, 3, 6, 2, 3, 3, 6])
plt.hist(types, bins = 7)
plt.xlabel('Spectral Type: O = 1, B = 2, A = 3, F = 4, G = 5, K = 6, M = 7' )
plt.ylabel('Number of stars of each spectral type')
plt.title('Stars in each spectral type in class data set', fontsize = 14)
plt.show()
